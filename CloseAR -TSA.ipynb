# %%
import pandas as pd

# %%
# !pip install scikit-learn==1.0.0

# !pip install statsmodels==0.12.2
# Out:
# Collecting scikit-learn==1.0.0
#   Downloading scikit_learn-1.0-cp37-cp37m-win_amd64.whl (7.1 MB)
#      ---------------------------------------- 7.1/7.1 MB 777.9 kB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.11 in c:\anaconda\envs\aiml\lib\site-packages (from scikit-learn==1.0.0) (1.3.2)
# Requirement already satisfied: numpy>=1.14.6 in c:\anaconda\envs\aiml\lib\site-packages (from scikit-learn==1.0.0) (1.17.4)
# Requirement already satisfied: scipy>=1.1.0 in c:\anaconda\envs\aiml\lib\site-packages (from scikit-learn==1.0.0) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\anaconda\envs\aiml\lib\site-packages (from scikit-learn==1.0.0) (3.1.0)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# Successfully installed scikit-learn-1.0
# Collecting statsmodels==0.12.2
#   Downloading statsmodels-0.12.2-cp37-none-win_amd64.whl (9.3 MB)
#      ---------------------------------------- 9.3/9.3 MB 732.4 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.15 in c:\anaconda\envs\aiml\lib\site-packages (from statsmodels==0.12.2) (1.17.4)
# Requirement already satisfied: pandas>=0.21 in c:\anaconda\envs\aiml\lib\site-packages (from statsmodels==0.12.2) (1.3.5)
# Requirement already satisfied: scipy>=1.1 in c:\anaconda\envs\aiml\lib\site-packages (from statsmodels==0.12.2) (1.7.3)
# Requirement already satisfied: patsy>=0.5 in c:\anaconda\envs\aiml\lib\site-packages (from statsmodels==0.12.2) (0.5.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\anaconda\envs\aiml\lib\site-packages (from pandas>=0.21->statsmodels==0.12.2) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\anaconda\envs\aiml\lib\site-packages (from pandas>=0.21->statsmodels==0.12.2) (2022.7)
# Requirement already satisfied: six in c:\anaconda\envs\aiml\lib\site-packages (from patsy>=0.5->statsmodels==0.12.2) (1.16.0)
# Installing collected packages: statsmodels
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.13.5
#     Uninstalling statsmodels-0.13.5:
#       Successfully uninstalled statsmodels-0.13.5
# Successfully installed statsmodels-0.12.2

# %%
from nsepy import get_history as gh
import datetime as dt

# %%
pip install --upgrade requests urllib3 certifi
# Out:
# Requirement already satisfied: requests in c:\anaconda\envs\aiml\lib\site-packages (2.31.0)
# Requirement already satisfied: urllib3 in c:\anaconda\envs\aiml\lib\site-packages (1.26.14)
# Collecting urllib3
#   Downloading urllib3-2.0.7-py3-none-any.whl (124 kB)
#      ------------------------------------ 124.2/124.2 kB 125.8 kB/s eta 0:00:00
# Requirement already satisfied: certifi in c:\anaconda\envs\aiml\lib\site-packages (2022.12.7)
# Collecting certifi
#   Downloading certifi-2026.1.4-py3-none-any.whl (152 kB)
#      ------------------------------------ 152.9/152.9 kB 228.3 kB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\envs\aiml\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda\envs\aiml\lib\site-packages (from requests) (2.0.4)
# Installing collected packages: urllib3, certifi
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.14
#     Uninstalling urllib3-1.26.14:
#       Successfully uninstalled urllib3-1.26.14
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2022.12.7
#     Uninstalling certifi-2022.12.7:
#       Successfully uninstalled certifi-2022.12.7
# Successfully installed certifi-2026.1.4 urllib3-2.0.7
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jugaad-data 0.29 requires beautifulsoup4==4.9.3, but you have beautifulsoup4 4.14.3 which is incompatible.

# %%
stk_data = pd.read_csv("Tatacoffee.csv")

stk_data
# Out:
#            Date     Open     High      Low    Close
# 0    2013-01-01  1410.60  1427.90  1408.30  1415.10
# 1    2013-01-02  1421.00  1626.60  1416.15  1607.40
# 2    2013-01-03  1632.55  1673.90  1613.05  1626.20
# 3    2013-01-04  1627.75  1627.75  1574.60  1579.05
# 4    2013-01-07  1580.00  1639.50  1565.50  1595.65
# ..          ...      ...      ...      ...      ...
# 489  2014-12-24   950.00   963.00   941.60   943.40
# 490  2014-12-26   944.95   950.00   936.00   939.25
# 491  2014-12-29   942.00   949.40   942.00   944.40
# 492  2014-12-30   947.40   949.85   942.00   946.50
# 493  2014-12-31   946.50   966.25   945.95   955.70
#
# [494 rows x 5 columns]

# %%
stk_data
# Out:
#                 Symbol Series  Prev Close    Open    High     Low    Last  \
# Date
# 2021-07-01  TATACOFFEE     EQ      187.65  188.60  189.00  183.00  185.20
# 2021-07-02  TATACOFFEE     EQ      184.55  183.05  187.50  182.15  186.50
# 2021-07-05  TATACOFFEE     EQ      186.40  187.85  198.35  187.85  193.00
# 2021-07-06  TATACOFFEE     EQ      192.45  193.80  194.80  187.35  189.90
# 2021-07-07  TATACOFFEE     EQ      188.80  187.80  193.95  185.40  193.15
# ...                ...    ...         ...     ...     ...     ...     ...
# 2022-01-21  TATACOFFEE     EQ      219.70  217.70  224.40  216.70  220.00
# 2022-01-24  TATACOFFEE     EQ      219.55  218.00  220.00  205.20  208.00
# 2022-01-25  TATACOFFEE     EQ      208.00  207.50  213.70  200.00  211.30
# 2022-01-27  TATACOFFEE     EQ      211.90  209.95  215.50  208.15  213.00
# 2022-01-28  TATACOFFEE     EQ      213.15  214.85  225.70  210.00  211.90
#
#              Close    VWAP    Volume      Turnover  Trades  \
# Date
# 2021-07-01  184.55  184.87   1743168  3.222523e+13   15602
# 2021-07-02  186.40  184.63   2398669  4.428696e+13   18505
# 2021-07-05  192.45  194.30  11386496  2.212345e+14   77851
# 2021-07-06  188.80  191.26   2841264  5.434218e+13   25393
# 2021-07-07  192.85  189.68   2795890  5.303306e+13   20822
# ...            ...     ...       ...           ...     ...
# 2022-01-21  219.55  220.62   2489247  5.491655e+13   21474
# 2022-01-24  208.00  211.31   1718571  3.631584e+13   19946
# 2022-01-25  211.90  209.96   1301360  2.732359e+13   14838
# 2022-01-27  213.15  212.41   1610303  3.420460e+13   21331
# 2022-01-28  212.40  218.29   4131610  9.018964e+13   42228
#
#             Deliverable Volume  %Deliverble
# Date
# 2021-07-01              457044       0.2622
# 2021-07-02              501165       0.2089
# 2021-07-05             2236477       0.1964
# 2021-07-06              780698       0.2748
# 2021-07-07              560578       0.2005
# ...                        ...          ...
# 2022-01-21              544576       0.2188
# 2022-01-24              250439       0.2139
# 2022-01-25              223337       0.1716
# 2022-01-27              340837       0.2117
# 2022-01-28              757621       0.1834
#
# [145 rows x 14 columns]

# %%
stk_data=stk_data[["Open","High","Low","Close"]]

# %%
stk_data
# Out:
#               Open    High     Low   Close
# Date
# 2021-07-01  188.60  189.00  183.00  184.55
# 2021-07-02  183.05  187.50  182.15  186.40
# 2021-07-05  187.85  198.35  187.85  192.45
# 2021-07-06  193.80  194.80  187.35  188.80
# 2021-07-07  187.80  193.95  185.40  192.85
# ...            ...     ...     ...     ...
# 2022-01-21  217.70  224.40  216.70  219.55
# 2022-01-24  218.00  220.00  205.20  208.00
# 2022-01-25  207.50  213.70  200.00  211.90
# 2022-01-27  209.95  215.50  208.15  213.15
# 2022-01-28  214.85  225.70  210.00  212.40
#
# [145 rows x 4 columns]

# %%
column="Close"

# %%
from sklearn.preprocessing import MinMaxScaler
Ms = MinMaxScaler()
data1= Ms.fit_transform(stk_data[[column]])
print("Len:",data1.shape)
# Out:
# Len: (494, 1)

# %%
len(data1)
# Out:
# 494

# %%
training_size = round(len(data1 ) * 0.80)
print(training_size)
X_train=data1[:training_size]
X_test=data1[training_size:]
print("X_train length:",X_train.shape)
print("X_test length:",X_test.shape)
y_train=data1[:training_size]
y_test=data1[training_size:]
print("y_train length:",y_train.shape)
print("y_test length:",y_test.shape)
# Out:
# 395
# X_train length: (395, 1)
# X_test length: (99, 1)
# y_train length: (395, 1)
# y_test length: (99, 1)

# %%
from sklearn.metrics import mean_squared_error
trends=['n','t','c','ct']
lags=[1,2,3,4]
from statsmodels.tsa.ar_model import AutoReg
for i in lags:
    #print(i)
   
    for td in trends:
        
        #print(td)
        #trendslist.append(td)
        model = AutoReg(X_train, lags=i,trend=td)
        model_fit = model.fit()
        # make prediction
        y_pred= model_fit.predict(len(X_train), len(data1)-1)
        #print(y_pred)
        #mse=mean_squared_error(y_test,y_pred,squared=False)
        from stockFunctions import rmsemape
        print("Lag={},Trend={}".format(i,td))
        rmsemape(y_test,y_pred)
        print("************")
# Out:
# Lag=1,Trend=n
# RMSE-Testset: 0.055591947946142056
# maPe-Testset: 0.4326835157504947
# ************
# Lag=1,Trend=t
# RMSE-Testset: 0.08431295685568405
# maPe-Testset: 0.6896206400423713
# ************
# Lag=1,Trend=c
# RMSE-Testset: 0.041690445576027156
# maPe-Testset: 0.38240194749773554
# ************
# Lag=1,Trend=ct
# RMSE-Testset: 0.21060398823915394
# maPe-Testset: 1.9679321559886598
# ************
# Lag=2,Trend=n
# RMSE-Testset: 0.06190756481411221
# maPe-Testset: 0.488149654048087
# ************
# Lag=2,Trend=t
# RMSE-Testset: 0.044346760234883986
# maPe-Testset: 0.38001033650007054
# ************
# Lag=2,Trend=c
# RMSE-Testset: 0.035459068641786155
# maPe-Testset: 0.4707666356286775
# ************
# Lag=2,Trend=ct
# RMSE-Testset: 0.1681805643450837
# maPe-Testset: 1.5278344400152133
# ************
# Lag=3,Trend=n
# RMSE-Testset: 0.06017763987625215
# maPe-Testset: 0.472095466138124
# ************
# Lag=3,Trend=t
# RMSE-Testset: 0.05405034915241228
# maPe-Testset: 0.421682535687783
# ************
# Lag=3,Trend=c
# RMSE-Testset: 0.03799993308461506
# maPe-Testset: 0.40444733190842963
# ************
# Lag=3,Trend=ct
# RMSE-Testset: 0.1569469271287885
# maPe-Testset: 1.3958338554414582
# ************
# Lag=4,Trend=n
# RMSE-Testset: 0.059910270101779614
# maPe-Testset: 0.4703137715814143
# ************
# Lag=4,Trend=t
# RMSE-Testset: 0.05508379151369986
# maPe-Testset: 0.43047725886489163
# ************
# Lag=4,Trend=c
# RMSE-Testset: 0.03671404716131256
# maPe-Testset: 0.41657095465938904
# ************
# Lag=4,Trend=ct
# RMSE-Testset: 0.17227686337034506
# maPe-Testset: 1.564428659396913
# ************
# C:\anaconda\envs\aiml\lib\site-packages\statsmodels\tsa\ar_model.py:252: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   FutureWarning,
# C:\anaconda\envs\aiml\lib\site-packages\statsmodels\tsa\ar_model.py:252: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   FutureWarning,
# C:\anaconda\envs\aiml\lib\site-packages\statsmodels\tsa\ar_model.py:252: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   FutureWarning,
# C:\anaconda\envs\aiml\lib\site-packages\statsmodels\tsa\ar_model.py:252: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   FutureWarning,
# C:\anaconda\envs\aiml\lib\site-packages\statsmodels\tsa\ar_model.py:252: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   FutureWarning,
# C:\anaconda\envs\aiml\lib\site-packages\statsmodels\tsa\ar_model.py:252: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   FutureWarning,
# C:\anaconda\envs\aiml\lib\site-packages\statsmodels\tsa\ar_model.py:252: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   FutureWarning,
# C:\anaconda\envs\aiml\lib\site-packages\statsmodels\tsa\ar_model.py:252: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   FutureWarning,
# C:\anaconda\envs\aiml\lib\site-packages\statsmodels\tsa\ar_model.py:252: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   FutureWarning,
# C:\anaconda\envs\aiml\lib\site-packages\statsmodels\tsa\ar_model.py:252: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   FutureWarning,
# C:\anaconda\envs\aiml\lib\site-packages\statsmodels\tsa\ar_model.py:252: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   FutureWarning,
# C:\anaconda\envs\aiml\lib\site-packages\statsmodels\tsa\ar_model.py:252: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   FutureWarning,
# C:\anaconda\envs\aiml\lib\site-packages\statsmodels\tsa\ar_model.py:252: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   FutureWarning,
# C:\anaconda\envs\aiml\lib\site-packages\statsmodels\tsa\ar_model.py:252: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   FutureWarning,
# C:\anaconda\envs\aiml\lib\site-packages\statsmodels\tsa\ar_model.py:252: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   FutureWarning,
# C:\anaconda\envs\aiml\lib\site-packages\statsmodels\tsa\ar_model.py:252: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   FutureWarning,

# %%
len(y_pred)
# Out:
# 99

# %%
i=3
td='c'
model = AutoReg(X_train, lags=i,trend=td)
model_fit = model.fit()
# make prediction
y_pred= model_fit.predict(len(X_train), len(data1)-1)
#print(y_pred)
from sklearn.metrics import r2_score
mse=mean_squared_error(y_test,y_pred,squared=False)
from stockFunctions import rmsemape
print("Lag={},Trend={}".format(i,td))
rmsemape(y_test,y_pred)
print("************")
# Out:
# Lag=3,Trend=c
# RMSE-Testset: 0.03799993308461506
# maPe-Testset: 0.40444733190842963
# ************
# C:\anaconda\envs\aiml\lib\site-packages\statsmodels\tsa\ar_model.py:252: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   FutureWarning,

# %%
from stockFunctions import graph
graph(y_test,y_pred,"Actual","Predicted","TataCoffee-Close-AR-Norm","Days","Prices")

# %%
len(data1)
# Out:
# 494

# %%
y_test
# Out:
# array([[0.06074313],
#        [0.06358643],
#        [0.06365105],
#        [0.0657189 ],
#        [0.06487884],
#        [0.0476252 ],
#        [0.04491115],
#        [0.0473021 ],
#        [0.03360258],
#        [0.02726979],
#        [0.05227787],
#        [0.04827141],
#        [0.04852989],
#        [0.05285945],
#        [0.04717286],
#        [0.04536349],
#        [0.0368336 ],
#        [0.03728595],
#        [0.03095315],
#        [0.03127625],
#        [0.03011309],
#        [0.02901454],
#        [0.05466882],
#        [0.05550889],
#        [0.10177706],
#        [0.11663974],
#        [0.10009693],
#        [0.10959612],
#        [0.12019386],
#        [0.13621971],
#        [0.07670436],
#        [0.09266559],
#        [0.10184168],
#        [0.1238126 ],
#        [0.12310178],
#        [0.09072698],
#        [0.10235864],
#        [0.05886914],
#        [0.06429725],
#        [0.05919225],
#        [0.06306947],
#        [0.05505654],
#        [0.0692084 ],
#        [0.06843296],
#        [0.07218094],
#        [0.06138934],
#        [0.06216478],
#        [0.06054927],
#        [0.04575121],
#        [0.04626817],
#        [0.04568659],
#        [0.0873021 ],
#        [0.0653958 ],
#        [0.07379645],
#        [0.05919225],
#        [0.05473344],
#        [0.05363489],
#        [0.05531502],
#        [0.07082391],
#        [0.06843296],
#        [0.06035541],
#        [0.0552504 ],
#        [0.07024233],
#        [0.05899838],
#        [0.05563813],
#        [0.0685622 ],
#        [0.06681745],
#        [0.1231664 ],
#        [0.1307916 ],
#        [0.10978998],
#        [0.13150242],
#        [0.11431341],
#        [0.12271405],
#        [0.13369952],
#        [0.17479806],
#        [0.17466882],
#        [0.1676252 ],
#        [0.16749596],
#        [0.16252019],
#        [0.18100162],
#        [0.16962843],
#        [0.1752504 ],
#        [0.1561874 ],
#        [0.13854604],
#        [0.13938611],
#        [0.13757674],
#        [0.13641357],
#        [0.12865913],
#        [0.10287561],
#        [0.07528271],
#        [0.09880452],
#        [0.10972536],
#        [0.1095315 ],
#        [0.09757674],
#        [0.08911147],
#        [0.08374798],
#        [0.09040388],
#        [0.09311793],
#        [0.10500808]])

# %%
from stockFunctions import conversionSingle
aTestNormTable=conversionSingle(y_test,[column])

# %%
aTestNormTable
# Out:
#        Close
# 0   0.060743
# 1   0.063586
# 2   0.063651
# 3   0.065719
# 4   0.064879
# ..       ...
# 94  0.089111
# 95  0.083748
# 96  0.090404
# 97  0.093118
# 98  0.105008
#
# [99 rows x 1 columns]

# %%
actual_stock_price_test_ori=Ms.inverse_transform(aTestNormTable)

# %%
actual_stock_price_test_ori
# Out:
# array([[ 921.45],
#        [ 923.65],
#        [ 923.7 ],
#        [ 925.3 ],
#        [ 924.65],
#        [ 911.3 ],
#        [ 909.2 ],
#        [ 911.05],
#        [ 900.45],
#        [ 895.55],
#        [ 914.9 ],
#        [ 911.8 ],
#        [ 912.  ],
#        [ 915.35],
#        [ 910.95],
#        [ 909.55],
#        [ 902.95],
#        [ 903.3 ],
#        [ 898.4 ],
#        [ 898.65],
#        [ 897.75],
#        [ 896.9 ],
#        [ 916.75],
#        [ 917.4 ],
#        [ 953.2 ],
#        [ 964.7 ],
#        [ 951.9 ],
#        [ 959.25],
#        [ 967.45],
#        [ 979.85],
#        [ 933.8 ],
#        [ 946.15],
#        [ 953.25],
#        [ 970.25],
#        [ 969.7 ],
#        [ 944.65],
#        [ 953.65],
#        [ 920.  ],
#        [ 924.2 ],
#        [ 920.25],
#        [ 923.25],
#        [ 917.05],
#        [ 928.  ],
#        [ 927.4 ],
#        [ 930.3 ],
#        [ 921.95],
#        [ 922.55],
#        [ 921.3 ],
#        [ 909.85],
#        [ 910.25],
#        [ 909.8 ],
#        [ 942.  ],
#        [ 925.05],
#        [ 931.55],
#        [ 920.25],
#        [ 916.8 ],
#        [ 915.95],
#        [ 917.25],
#        [ 929.25],
#        [ 927.4 ],
#        [ 921.15],
#        [ 917.2 ],
#        [ 928.8 ],
#        [ 920.1 ],
#        [ 917.5 ],
#        [ 927.5 ],
#        [ 926.15],
#        [ 969.75],
#        [ 975.65],
#        [ 959.4 ],
#        [ 976.2 ],
#        [ 962.9 ],
#        [ 969.4 ],
#        [ 977.9 ],
#        [1009.7 ],
#        [1009.6 ],
#        [1004.15],
#        [1004.05],
#        [1000.2 ],
#        [1014.5 ],
#        [1005.7 ],
#        [1010.05],
#        [ 995.3 ],
#        [ 981.65],
#        [ 982.3 ],
#        [ 980.9 ],
#        [ 980.  ],
#        [ 974.  ],
#        [ 954.05],
#        [ 932.7 ],
#        [ 950.9 ],
#        [ 959.35],
#        [ 959.2 ],
#        [ 949.95],
#        [ 943.4 ],
#        [ 939.25],
#        [ 944.4 ],
#        [ 946.5 ],
#        [ 955.7 ]])

# %%
actual_stock_price_test_oriA=conversionSingle(actual_stock_price_test_ori,[column])

# %%
actual_stock_price_test_oriA
# Out:
#      Close
# 0   921.45
# 1   923.65
# 2    923.7
# 3    925.3
# 4   924.65
# ..     ...
# 94   943.4
# 95  939.25
# 96   944.4
# 97   946.5
# 98   955.7
#
# [99 rows x 1 columns]

# %%
from stockFunctions import conversionSingle
aTestNormTable=conversionSingle(y_test,[column])
actual_stock_price_test_ori=Ms.inverse_transform(aTestNormTable)
actual_stock_price_test_oriA=conversionSingle(actual_stock_price_test_ori,[column])

# %%
from stockFunctions import conversionSingle
pTestNormTable=conversionSingle(y_pred,[column])
predicted_stock_price_test_ori=Ms.inverse_transform(pTestNormTable)
predicted_stock_price_test_oriP=conversionSingle(predicted_stock_price_test_ori,[column])

# %%
from stockFunctions import graph
graph(actual_stock_price_test_oriA,predicted_stock_price_test_oriP,"Actual","Predicted","TataCoffee-Close-AR-Ori","Days","Prices")

# %%
from stockFunctions import rmsemape
rmsemape(actual_stock_price_test_oriA,predicted_stock_price_test_oriP)
# Out:
# RMSE-Testset: 29.402448224220908
# maPe-Testset: 0.0249535422863995

# %%
forecast=model_fit.predict(len(data1), len(data1)+3)

# %%
forecast
# Out:
# array([0.08643733, 0.08653727, 0.0866363 , 0.08673443])

# %%
from stockFunctions import conversionSingle
fTestNormTable=conversionSingle(forecast,["Closefore"])
forecast_stock_price_test_ori=Ms.inverse_transform(fTestNormTable)
forecast_stock_price_test_oriF=conversionSingle(forecast_stock_price_test_ori,["Closefore"])

# %%
forecast_stock_price_test_oriF
# Out:
#     Closefore
# 0  941.330884
# 1  941.408215
# 2  941.484841
# 3  941.560767

# %%
forecast_stock_price_test_oriF.to_csv("CloseAR.csv",index=False)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
plt.plot(actual_stock_price_test_oriA[116:145], color = 'blue', label="Actual")
plt.plot(forecast_stock_price_test_oriF, color = 'red', label ="Predicted")
